# %%
import tensorflow as tf

# %%
input_shape=(224,224)
train_take=.8
test_take=.5

# %%
import math
train_ds = tf.keras.utils.image_dataset_from_directory(
  'data',
  validation_split=1-train_take,
  subset="training",
  seed=123,
  image_size=input_shape,
  batch_size=32).shuffle(1000)
non_train_ds = tf.keras.utils.image_dataset_from_directory(
  'data',
  validation_split=1-train_take,
  subset="validation",
  seed=123,
  image_size=input_shape,
  batch_size=32).shuffle(1000)
val_ds=non_train_ds.take(math.ceil(non_train_ds.cardinality().numpy()*(1-test_take)))
test_ds=non_train_ds.take(math.floor(non_train_ds.cardinality().numpy()*(test_take)))
print("train size: "+str(train_ds.cardinality()))
print("val size: "+str(val_ds.cardinality()))
print("test size: "+str(test_ds.cardinality()))
# Out:
# Found 4188 files belonging to 4 classes.
# Using 3351 files for training.
# Found 4188 files belonging to 4 classes.
# Using 837 files for validation.
# train size: tf.Tensor(105, shape=(), dtype=int64)
# val size: tf.Tensor(14, shape=(), dtype=int64)
# test size: tf.Tensor(13, shape=(), dtype=int64)

# %%
class_names=['Blight','Common Rust','Gray Leaf Spot','Healthy']

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
#Use MobileNet for trasnsfer learning
base_model=tf.keras.applications.mobilenet_v2.MobileNetV2(include_top=False)
for layer in base_model.layers:
    layer.trainable=False
preprocessed=tf.keras.applications.mobilenet_v2.preprocess_input(base_model.input)
base_model_output=base_model(preprocessed)
avg=tf.keras.layers.GlobalAveragePooling2D()(base_model_output)
hidden=tf.keras.layers.Dense(32,activation='relu')(avg)
output=tf.keras.layers.Dense(len(class_names),activation='softmax')(hidden)
model=tf.keras.Model(inputs=base_model.input,outputs=output)
model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, None, None, 3)]   0
#
#  tf.math.truediv (TFOpLambda  (None, None, None, 3)    0
#  )
#
#  tf.math.subtract (TFOpLambd  (None, None, None, 3)    0
#  a)
#
#  mobilenetv2_1.00_224 (Funct  (None, None, None, 1280)  2257984
#  ional)
#
#  global_average_pooling2d (G  (None, 1280)             0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 32)                40992
#
#  dense_1 (Dense)             (None, 4)                 132
#
# =================================================================
# Total params: 2,299,108
# Trainable params: 41,124
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
model.compile('nadam',loss='sparse_categorical_crossentropy',metrics='accuracy')
model.fit(train_ds,validation_data=val_ds,epochs=10,callbacks=[tf.keras.callbacks.EarlyStopping(min_delta=0,patience=3)])
# Out:
# Epoch 1/10
# 105/105 [==============================] - 23s 107ms/step - loss: 0.3732 - accuracy: 0.8591 - val_loss: 0.2309 - val_accuracy: 0.9152
# Epoch 2/10
# 105/105 [==============================] - 14s 94ms/step - loss: 0.1799 - accuracy: 0.9305 - val_loss: 0.2414 - val_accuracy: 0.9074
# Epoch 3/10
# 105/105 [==============================] - 14s 90ms/step - loss: 0.1356 - accuracy: 0.9466 - val_loss: 0.2286 - val_accuracy: 0.9107
# Epoch 4/10
# 105/105 [==============================] - 14s 91ms/step - loss: 0.1076 - accuracy: 0.9579 - val_loss: 0.2070 - val_accuracy: 0.9240
# Epoch 5/10
# 105/105 [==============================] - 14s 95ms/step - loss: 0.0894 - accuracy: 0.9666 - val_loss: 0.2047 - val_accuracy: 0.9040
# Epoch 6/10
# 105/105 [==============================] - 14s 95ms/step - loss: 0.0684 - accuracy: 0.9782 - val_loss: 0.2449 - val_accuracy: 0.9002
# Epoch 7/10
# 105/105 [==============================] - 14s 94ms/step - loss: 0.0586 - accuracy: 0.9827 - val_loss: 0.2474 - val_accuracy: 0.9050
# Epoch 8/10
# 105/105 [==============================] - 14s 95ms/step - loss: 0.0448 - accuracy: 0.9878 - val_loss: 0.3466 - val_accuracy: 0.9026

# %%
import numpy as np
confusion_matrix=np.zeros([4,4])
true_labels=np.zeros([14*32])
predictions=np.zeros([14*32])
i=0
for item in val_ds:
    output=model.predict(item[0])
    output=np.argmax(output,axis=-1)
    for true,prediction in zip(item[1],output):
        true_labels[i]=true.numpy()
        predictions[i]=prediction
        i+=1
from sklearn.metrics import confusion_matrix
confusion_mat=np.float32(confusion_matrix(true_labels,predictions))
print(confusion_mat)
# Out:
# 1/1 [==============================] - 1s 705ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# [[106.   3.   5.   0.]
#  [  5. 135.   0.   0.]
#  [ 28.   0.  32.   0.]
#  [  0.   0.   0. 134.]]

# %%
for i,row in enumerate(confusion_mat):
    confusion_mat[i]/=np.sum(row)
print(confusion_mat)
# Out:
# [[0.9298246  0.02631579 0.04385965 0.        ]
#  [0.03571429 0.96428573 0.         0.        ]
#  [0.46666667 0.         0.53333336 0.        ]
#  [0.         0.         0.         1.        ]]

# %%
import matplotlib.pyplot as plt
plt.matshow(confusion_mat,cmap=plt.cm.gray)
